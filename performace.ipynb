# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(4)
y15 = [23, 6, 0, 0]
y30 = [19, 5, 0, 0]
y50 = [10, 3, 0, 0]
yPPO = [0, 0, 213, 56]
width = 0.27

rects1 = plt.bar(x-(width+width/2), y15, width, label='Pop. size 15')
rects2 = plt.bar(x-(width/2), y30, width, label='Pop. size 30')
rects3 = plt.bar(x+width/2, y50, width, label='Pop. size 50')
rects4 = plt.bar(x, yPPO, width, label='Individual episodes')

plt.xticks(x, ['NEAT - unconnected', 'NEAT - full', 'PPO-v1', 'PPO-v2'])
plt.xlabel("ML Algorithms")
plt.ylabel("Avg. no. of generations")
plt.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


        
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)


fig.tight_layout()
plt.rcParams["figure.figsize"] = (10, 6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

time = 640
#x = np.arange(time)

#ynao = np.linspace(0,13.4, 21)
#ynao = [0, 1.2, 1.5, 1.8, 2.1, 2.3, ]
yu15 = [0, 1.21, 1.21, 1.21, 1.21, 1.21,1.21, 1.21, 1.21, 1.80, 1.97, 1.80, 3.18, 2.59, 2.89, 2.36, 2.81, 6.76, 4.94, 4.76, 4.96] 
yu30 = [1.21, 1.21, 1.22, 1.21, 1.61, 2.39, 3.69, 5.20, 3.92, 4.03, 4.32, 4.92, 4.80, 5.04]
yu50 = [0, 1.21, 1.22, 2.40, 3.58, 3.98, 5.31, 4.66, 8.00, 7.53, 12.29, 14.37, 12.97, 12.62, 15.41, 12.68, 13.72, 13.99, 12.48, 15.33, 11.45]
yf15 = [0, 7.43, 8.72, 14.99, 14.21, 13.95, 9.44, 9.76, 10.34, 11.21, 10.41, 10.67, 12.4, 16.16, 7.07, 8.5, 14.24, 10.37, 12.43, 14.3, 12.67]
yf30 = [0, 10.33, 16.47, 13.88, 15.26, 16.16, 15.0, 10.72, 8.53, 15.89, 10.71, 11.81, 10.02, 11.67, 14.52, 15.10, 14.58, 11.57, 10.94, 7.46, 12.32]
yf50 = [0, 11.97, 10.63, 14.33,15.38, 13.4, 13.38, 15.26, 13.07, 12.48, 17.45, 13.78, 12.86, 15.59, 12.48, 13.43, 14.56, 12.32, 11.46, 15.6, 8.78]
ppo1 = [0, 6.93, 6.92, 7.43, 8.24, 7.92, 7.27, 7.92 ,7.37, 8.71, 7.86, 8.34, 7.68, 8.14, 8.30, 8.65, 7.64, 8.22, 7.79, 8.45, 8.19]
ppo2 = [0, 8.32, 9.41, 9.82, 9.58, 9.27, 11.26, 9.61, 10.98, 8.57, 9.26, 8.95, 11.20, 9.74, 10.66, 9.61, 9.71, 11.37, 11.6, 11.86, 10.43]

x = np.linspace(0, time, 21)

plt.plot(x, yu50, 'o-', label = "NEAT unconnected, pop. size 50")
plt.plot(x, yu15, 'o-', label = "NEAT unconnected, pop. size 15")
plt.plot(x, yf50, 'o-', label = "NEAT full, pop. size 50")
plt.plot(x, yf30, 'o-', label = "NEAT full, pop. size 30")
plt.plot(x, yf15, 'o-', label = "NEAT full, pop. size 15")
plt.plot(x, ppo1, 'o-', label = "PPO-v1")
plt.plot(x, ppo2, 'o-', label = "PPO-v2")


#plt.plot(x, ynao, 'o-', label = "Approximated angle evolution for Nao")

plt.title("")
plt.xlabel("Time (Seconds)")
plt.ylabel("Maximum angle (degrees)")
plt.legend()
#fig.tight_layout()
plt.show()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(2)
y15 = [23, 6]
y30 = [19, 5]
y50 = [10, 3]
#yPPO = [0, 0, 213, 56]
width = 0.27

rects1 = plt.bar(x-(width+width/2), y15, width, label='Pop. size 15')
rects2 = plt.bar(x-(width/2), y30, width, label='Pop. size 30')
rects3 = plt.bar(x+width/2, y50, width, label='Pop. size 50')
#rects4 = plt.bar(x, yPPO, width, label='Individual episodes')

plt.xticks(x, ['NEAT - unconnected', 'NEAT - full'])
plt.xlabel("ML Algorithms")
plt.ylabel("Avg. no. of generations")
plt.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


        
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
#autolabel(rects4)


fig.tight_layout()
plt.rcParams["figure.figsize"] = (10, 6)
plt.show()
